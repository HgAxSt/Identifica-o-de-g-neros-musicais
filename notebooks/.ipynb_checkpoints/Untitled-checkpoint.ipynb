# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from typing import List
import os
from sklearn.tree import export_text


df = pd.read_csv(r"C:\Users\hugos\Downloads\archive\Data\features_3_sec.csv")
#df = pd.read_csv("features_3_sec.csv") para outros computadores sem ser o meu
df.head()
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1  blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2  blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3  blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4  blues.00000.4.wav   66149          0.335579         0.088129  0.143289
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.003521             1773.065032          167541.630869
# 1  0.001450             1816.693777           90525.690866
# 2  0.004620             1788.539719          111407.437613
# 3  0.002448             1655.289045          111952.284517
# 4  0.001701             1630.656199           79667.267654
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              1972.744388           117335.771563  ...   39.687145
# ...

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (9990, 60)
# filename                    object
# length                       int64
# chroma_stft_mean           float64
# chroma_stft_var            float64
# rms_mean                   float64
# rms_var                    float64
# spectral_centroid_mean     float64
# spectral_centroid_var      float64
# spectral_bandwidth_mean    float64
# spectral_bandwidth_var     float64
# rolloff_mean               float64
# rolloff_var                float64
# zero_crossing_rate_mean    float64
# zero_crossing_rate_var     float64
# harmony_mean               float64
# harmony_var                float64
# perceptr_mean              float64
# perceptr_var               float64
# tempo                      float64
# mfcc1_mean                 float64
# mfcc1_var                  float64
# mfcc2_mean                 float64
# mfcc2_var                  float64
# mfcc3_mean                 float64
# mfcc3_var                  float64
# mfcc4_mean                 float64
# ...

# %%
print(df.isnull().sum())
# Out:
# filename                   0
# length                     0
# chroma_stft_mean           0
# chroma_stft_var            0
# rms_mean                   0
# rms_var                    0
# spectral_centroid_mean     0
# spectral_centroid_var      0
# spectral_bandwidth_mean    0
# spectral_bandwidth_var     0
# rolloff_mean               0
# rolloff_var                0
# zero_crossing_rate_mean    0
# zero_crossing_rate_var     0
# harmony_mean               0
# harmony_var                0
# perceptr_mean              0
# perceptr_var               0
# tempo                      0
# mfcc1_mean                 0
# mfcc1_var                  0
# mfcc2_mean                 0
# mfcc2_var                  0
# mfcc3_mean                 0
# mfcc3_var                  0
# mfcc4_mean                 0
# mfcc4_var                  0
# mfcc5_mean                 0
# mfcc5_var                  0
# mfcc6_mean                 0
# mfcc6_var                  0
# mfcc7_mean                 0
# ...

# %%
print(df['label'].value_counts())
# Out:
# label
# blues        1000
# jazz         1000
# pop          1000
# reggae       1000
# metal        1000
# disco         999
# classical     998
# hiphop        998
# rock          998
# country       997
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#         length  chroma_stft_mean  chroma_stft_var     rms_mean       rms_var  \
# count   9990.0       9990.000000      9990.000000  9990.000000  9.990000e+03
# mean   66149.0          0.379534         0.084876     0.130859  2.676388e-03
# std        0.0          0.090466         0.009637     0.068545  3.585628e-03
# min    66149.0          0.107108         0.015345     0.000953  4.379535e-08
# 25%    66149.0          0.315698         0.079833     0.083782  6.145900e-04
# 50%    66149.0          0.384741         0.085108     0.121253  1.491318e-03
# 75%    66149.0          0.442443         0.091092     0.176328  3.130862e-03
# max    66149.0          0.749481         0.120964     0.442567  3.261522e-02
#
#        spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# count             9990.000000           9.990000e+03              9990.000000
# mean              2199.219431           4.166727e+05              2241.385959
# ...

# %%
print('----------------------------------------------------------------------------------------')
# Out:
# ----------------------------------------------------------------------------------------

# %%
#Removendo colunas que não são features
df_clean = df.drop(columns=['filename', 'length'])

# %%
X = df_clean.drop(columns=['label'])
y = df_clean['label']

print("Features shape:", X.shape)
print("Label shape:", y.shape)
print("Colunas mantidas:", list(X.columns))
# Out:
# Features shape: (9990, 57)
# Label shape: (9990,)
# Colunas mantidas: ['chroma_stft_mean', 'chroma_stft_var', 'rms_mean', 'rms_var', 'spectral_centroid_mean', 'spectral_centroid_var', 'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean', 'rolloff_var', 'zero_crossing_rate_mean', 'zero_crossing_rate_var', 'harmony_mean', 'harmony_var', 'perceptr_mean', 'perceptr_var', 'tempo', 'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean', 'mfcc2_var', 'mfcc3_mean', 'mfcc3_var', 'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var', 'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean', 'mfcc8_var', 'mfcc9_mean', 'mfcc9_var', 'mfcc10_mean', 'mfcc10_var', 'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean', 'mfcc12_var', 'mfcc13_mean', 'mfcc13_var', 'mfcc14_mean', 'mfcc14_var', 'mfcc15_mean', 'mfcc15_var', 'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_mean', 'mfcc18_var', 'mfcc19_mean', 'mfcc19_var', 'mfcc20_mean', 'mfcc20_var']

# %%
#1 aqui vou transformar os labels textuais em numérico
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
# 2. Dividir em treino e teste (80% treino, 20% teste)
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42
)

# %%
# 3. Normalizar os atributos
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print("Treino:", X_train.shape)
print("Teste:", X_test.shape)
print("Classes:", le.classes_)
# Out:
# Treino: (7992, 57)
# Teste: (1998, 57)
# Classes: ['blues' 'classical' 'country' 'disco' 'hiphop' 'jazz' 'metal' 'pop'
#  'reggae' 'rock']

# %%
# Treinar o modelo
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)

# Fazer previsões
y_pred_dt = dt.predict(X_test)

# Avaliar
print("Acurácia:", accuracy_score(y_test, y_pred_dt))
print("\nRelatório completo:")
print(classification_report(y_test, y_pred_dt, target_names=le.classes_))
# Out:
# Acurácia: 0.6571571571571572
#
# Relatório completo:
#               precision    recall  f1-score   support
#
#        blues       0.61      0.59      0.60       208
#    classical       0.86      0.82      0.84       203
#      country       0.54      0.57      0.56       186
#        disco       0.58      0.53      0.55       199
#       hiphop       0.69      0.66      0.67       218
#         jazz       0.67      0.73      0.70       192
#        metal       0.72      0.73      0.72       204
#          pop       0.73      0.82      0.77       180
#       reggae       0.66      0.62      0.64       211
#         rock       0.51      0.53      0.52       197
#
#     accuracy                           0.66      1998
#    macro avg       0.66      0.66      0.66      1998
# weighted avg       0.66      0.66      0.66      1998

# %%
print("\n--- Dicionário Rápido ---")
print("Precision = Certeza do chute")
print("Recall = Capacidade de achar")
print("F1-Score = Nota final balanceada")
print("Support = Quantidade real existente")
print("Accuracy = Acertos no total")
# Out:
# --- Dicionário Rápido ---
# Precision = Certeza do chute
# Recall = Capacidade de achar
# F1-Score = Nota final balanceada
# Support = Quantidade real existente
# Accuracy = Acertos no total

# %%
tree_rules = export_text(dt, feature_names=list(X.columns))
print(tree_rules)
# Out:
# |--- perceptr_var <= -0.82
# |   |--- rolloff_var <= -0.47
# |   |   |--- zero_crossing_rate_mean <= -1.59
# |   |   |   |--- perceptr_var <= -0.84
# |   |   |   |   |--- class: 1
# |   |   |   |--- perceptr_var >  -0.84
# |   |   |   |   |--- mfcc14_var <= -0.00
# |   |   |   |   |   |--- mfcc7_mean <= 1.22
# |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- mfcc7_mean >  1.22
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- mfcc14_var >  -0.00
# |   |   |   |   |   |--- class: 2
# |   |   |--- zero_crossing_rate_mean >  -1.59
# |   |   |   |--- perceptr_mean <= 0.56
# |   |   |   |   |--- spectral_bandwidth_mean <= -0.25
# |   |   |   |   |   |--- mfcc15_mean <= -1.83
# |   |   |   |   |   |   |--- mfcc1_mean <= -2.22
# |   |   |   |   |   |   |   |--- mfcc11_mean <= -0.96
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- mfcc11_mean >  -0.96
# |   |   |   |   |   |   |   |   |--- class: 1
# ...

# %%
cm = confusion_matrix(y_test, y_pred_dt)

fig, ax = plt.subplots(figsize=(8, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le.classes_)
disp.plot(cmap='Blues', ax=ax, xticks_rotation='vertical')

plt.show()

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

mlp_otimizada = MLPClassifier(
    hidden_layer_sizes=(128, 64, 32),
    activation='tanh',
    alpha=0.01,
    max_iter=500,
    random_state=42
)

mlp_otimizada.fit(X_train, y_train)

y_pred_mlp = mlp_otimizada.predict(X_test)

print("Acurácia MLP Otimizada:", accuracy_score(y_test, y_pred_mlp))
print("\nRelatório completo MLP Otimizada:")
print(classification_report(y_test, y_pred_mlp, target_names=le.classes_))
# Out:
# Acurácia MLP Otimizada: 0.8913913913913913
#
# Relatório completo MLP Otimizada:
#               precision    recall  f1-score   support
#
#        blues       0.84      0.91      0.88       208
#    classical       0.96      0.93      0.94       203
#      country       0.83      0.86      0.84       186
#        disco       0.87      0.87      0.87       199
#       hiphop       0.91      0.88      0.89       218
#         jazz       0.87      0.91      0.89       192
#        metal       0.95      0.93      0.94       204
#          pop       0.89      0.94      0.92       180
#       reggae       0.89      0.88      0.88       211
#         rock       0.91      0.81      0.86       197
#
#     accuracy                           0.89      1998
#    macro avg       0.89      0.89      0.89      1998
# weighted avg       0.89      0.89      0.89      1998

# %%
cm_mlp = confusion_matrix(y_test, y_pred_mlp)

fig, ax = plt.subplots(figsize=(10, 8))
disp_mlp = ConfusionMatrixDisplay(confusion_matrix=cm_mlp, display_labels=le.classes_)
disp_mlp.plot(cmap='Oranges', ax=ax, xticks_rotation='vertical')

plt.title("Matriz de Confusão - Rede Neural (MLP)")
plt.show()

# %%
def plot_feature_importance(model: DecisionTreeClassifier, feature_names: List[str], top_n: int = 10) -> None:
    importances = model.feature_importances_
    indices = np.argsort(importances)[::-1][:top_n]
    top_features = [feature_names[i] for i in indices]

    plt.figure(figsize=(10, 6))
    plt.title(f"Top {top_n} - Importância das Features Acústicas (Decision Tree)")
    plt.bar(range(top_n), importances[indices], align="center", color="teal")
    plt.xticks(range(top_n), top_features, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

plot_feature_importance(dt, list(X.columns), top_n=10)

# %%
def save_project_plot(fig: plt.Figure, filename: str, output_dir: str = "output") -> None:
    os.makedirs(output_dir, exist_ok=True)
    filepath = os.path.join(output_dir, filename)
    fig.savefig(filepath, dpi=300, bbox_inches='tight')
    plt.close(fig)

cm_dt = confusion_matrix(y_test, y_pred_dt)
fig_dt, ax_dt = plt.subplots(figsize=(8, 8))
disp_dt = ConfusionMatrixDisplay(confusion_matrix=cm_dt, display_labels=le.classes_)
disp_dt.plot(cmap='Blues', ax=ax_dt, xticks_rotation='vertical')
ax_dt.set_title("Matriz de Confusão - Árvore de Decisão")
save_project_plot(fig_dt, "matriz_confusao_decision_tree.png")

cm_mlp = confusion_matrix(y_test, y_pred_mlp)
fig_mlp, ax_mlp = plt.subplots(figsize=(10, 8))
disp_mlp = ConfusionMatrixDisplay(confusion_matrix=cm_mlp, display_labels=le.classes_)
disp_mlp.plot(cmap='Oranges', ax=ax_mlp, xticks_rotation='vertical')
ax_mlp.set_title("Matriz de Confusão - Rede Neural (MLP)")
save_project_plot(fig_mlp, "matriz_confusao_mlp.png")
